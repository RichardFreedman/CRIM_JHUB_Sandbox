# %% [markdown]
# # EMA 2 Intervals

# %% [markdown]
# ### A.  Import CRIM Intervals

# %%
import intervals
from intervals import ema2ex
from intervals import importScore 
import intervals.visualizations as viz
import pandas as pd
import re
import altair as alt 
from ipywidgets import interact
from pandas.io.json import json_normalize
from pyvis.network import Network
from IPython.display import display
import requests
import os

# You should change 'test' to your preferred folder.
MYDIR = ("saved_csv")
CHECK_FOLDER = os.path.isdir(MYDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)

else:
    print(MYDIR, "folder already exists.")
# Out:
# saved_csv folder already exists.

# %%
piece = importScore('https://crimproject.org/mei/CRIM_Model_0008.mei')

# piece = importScore('https://raw.githubusercontent.com/RichardFreedman/CRIM_additional_works/main/MEI/Palestrina_MIOM_1.musicxml')
# Out:
# Downloading remote score...
# Successfully imported https://crimproject.org/mei/CRIM_Model_0008.mei

# %% [markdown]
# ### F. Search for Patterns with Score Selection and ema2ex
#
# * Select EMA with the Continuo Tool or CRIM website
# * Paste the **`EMA address`** (the measures/staves/beats only) into the **`ema2ex`** field below
# * Make sure you import correct **score** of the piece!
# * Check **`kind`** for `"d"` or `"c"` as needed
# * Read the **`ngrams`** and use these to build the **cadence library**

# %%
piece = importScore('https://crimproject.org/mei/CRIM_Model_0033.mei')
mel = piece.getMelodic(kind="d", compound=True)

nr = piece.getNoteRest()
har = piece.getHarmonic('d')
mods = piece.getNgrams(df=har, n=-1, how='modules', exclude=['Rest'])

detNr = piece.detailIndex(nr, offset=True)
excerpt = ema2ex('3-5/1,1-2+4,2+4/@4,@1-3+@3+@1-4.5,@1-3+@1', detNr)
excerptOffsets = excerpt.index.get_level_values(2)
har_clip = har.loc[excerptOffsets, :]
mel_clip = mel.loc[excerptOffsets, :]
# mod_clip = mods.loc[excerptOffsets, :]
# here put in har_clip or mel_clip

ngrams = piece.getNgrams(df=har_clip, n=-1, how='modules').dropna()
# display(excerptOffsets)
display(ngrams)
# Out:
# Downloading remote score...
# Successfully imported https://crimproject.org/mei/CRIM_Model_0033.mei
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 12>()
#      10 excerptOffsets = excerpt.index.get_level_values(2)
#      11 har_clip = har.loc[excerptOffsets, :]
# ---> 12 mel_clip = mel.loc[excerptOffsets, :]
#      13 # mod_clip = mods.loc[excerptOffsets, :]
#      14 # here put in har_clip or mel_clip
#      16 ngrams = piece.getNgrams(df=har_clip, n=-1, how='modules').dropna()
#
# File ~/opt/anaconda3/envs/intervals-dev/lib/python3.9/site-packages/pandas/core/indexing.py:889, in _LocationIndexer.__getitem__(self, key)
#     886         with suppress(KeyError, IndexError, AttributeError):
#     887             # AttributeError for IntervalTree get_value
#     888             return self.obj._get_value(*key, takeable=self._takeable)
# --> 889     return self._getitem_tuple(key)
#     890 else:
#     891     # we by definition only have the 0th axis
#     892     axis = self.axis or 0
#
# File ~/opt/anaconda3/envs/intervals-dev/lib/python3.9/site-packages/pandas/core/indexing.py:1069, in _LocIndexer._getitem_tuple(self, tup)
#    1066 if self._multi_take_opportunity(tup):
#    1067     return self._multi_take(tup)
# -> 1069 return self._getitem_tuple_same_dim(tup)
#
# File ~/opt/anaconda3/envs/intervals-dev/lib/python3.9/site-packages/pandas/core/indexing.py:775, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     772 if com.is_null_slice(key):
#     773     continue
# --> 775 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776 # We should never have retval.ndim < self.ndim, as that should
#     777 #  be handled by the _getitem_lowerdim call above.
#     778 assert retval.ndim == self.ndim
#
# File ~/opt/anaconda3/envs/intervals-dev/lib/python3.9/site-packages/pandas/core/indexing.py:1113, in _LocIndexer._getitem_axis(self, key, axis)
#    1110     if hasattr(key, "ndim") and key.ndim > 1:
#    1111         raise ValueError("Cannot index with multidimensional key")
# -> 1113     return self._getitem_iterable(key, axis=axis)
#    1115 # nested tuple slicing
#    1116 if is_nested_tuple(key, labels):
#
# File ~/opt/anaconda3/envs/intervals-dev/lib/python3.9/site-packages/pandas/core/indexing.py:1053, in _LocIndexer._getitem_iterable(self, key, axis)
#    1050 self._validate_key(key, axis)
#    1052 # A collection of keys
# -> 1053 keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054 return self.obj._reindex_with_indexers(
#    1055     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1056 )
#
# File ~/opt/anaconda3/envs/intervals-dev/lib/python3.9/site-packages/pandas/core/indexing.py:1266, in _LocIndexer._get_listlike_indexer(self, key, axis, raise_missing)
#    1263 else:
#    1264     keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
# -> 1266 self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267 return keyarr, indexer
#
# File ~/opt/anaconda3/envs/intervals-dev/lib/python3.9/site-packages/pandas/core/indexing.py:1321, in _LocIndexer._validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1318 not_found = key[missing_mask]
#    1320 with option_context("display.max_seq_items", 10, "display.width", 80):
# -> 1321     raise KeyError(
#    1322         "Passing list-likes to .loc or [] with any missing labels "
#    1323         "is no longer supported. "
#    1324         f"The following labels were missing: {not_found}. "
#    1325         "See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"  # noqa:E501
#    1326     )
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Float64Index([22.0], dtype='float64', name='Offset'). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"
